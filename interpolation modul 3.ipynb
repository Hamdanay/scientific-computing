# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamdanay/scientific-computing/blob/main/interpolation%20modul%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# %%
x = [0, 1 ,2]
y = [1, 3, 2]

f = interp1d(x, y)

y_hat = (1.5)
print(y_hat)
# Out:
# 1.5

# %%
plt.figure(figsize=(10, 8))
plt.plot(x, y, '-ob')
plt.plot(1.5, y_hat, 'ro')
plt.title('linear interpolation at x = 1.5')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def divided_diff(x, y):
    n = len(y)
    coef = np.zeros([n, n])  # Membuat tabel kosong untuk divided differences
    coef[:, 0] = y  # Kolom pertama berisi nilai y

    for j in range(1, n):  # Loop untuk mengisi kolom-kolom berikutnya
        for i in range(n - j):
            coef[i][j] = (coef[i + 1][j - 1] - coef[i][j - 1]) / (x[i + j] - x[i])

    return coef
def newton_poly(coef, x_data, x):
    n = len(x_data) - 1
    p = coef[n]

    for k in range(1, n + 1):
        p = coef[n - k] + (x - x_data[n - k]) * p

    return p

# %%
x = np.array([-5, -1, 0, 2])
y = np.array([-2, 6, 1, 3])

# Menghitung koefisien divided difference
a_s = divided_diff(x, y)[0, :]

# Evaluasi interpolasi pada titik-titik baru
x_new = np.arange(-5, 2.1, .1)
y_new = newton_poly(a_s, x, x_new)

# Membuat plot
plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo')  # Menampilkan titik data asli
plt.plot(x_new, y_new)  # Menampilkan kurva interpolasi

# %%
from scipy.interpolate import CubicSpline
import numpy as np
import matplotlib.pyplot as plt

x = [0, 1, 2] #titik data pada sumbu x
y = [1, 3, 2] #titik data pada sumbu y

# membuat fungsi interpolasi kubik dengan batas natural
f = CubicSpline(x, y, bc_type='natural')

#membuat rentang nilai x untuk plot hasil interpolasi
x_new = np.linspace(0, 2, 100) #100 titik antara 0 dan 2
y_new = f(x_new) #menghitung nilai y dengan interpolasi kubik

#membuat plot
plt.figure(figsize=(10, 8)) #membuat plot 10x8 inci
plt.plot(x_new, y_new, 'b-') #menampilkan kurva interpolasi dalam warna biru
plt.plot(x, y, 'ro') #menampilkan titik dat asli dalamwarna merah
plt.title('Cubic Spline Interpolation') #judul grafik
plt.xlabel('x') #
plt.ylabel('y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# jarak dan kecepatan
x = np.array([0, 5, 10])
y = np.array([10, 15, 20])


f = interp1d(x, y, kind='linear')

# buat rentang x untuk haasil interpolasi
x_new = np.linspace(0, 10, 100)
y_new = f(x_new)

# Titik yang diinterpolasi
x_target = 7.2
y_target = f(x_target)

# buat plot
plt.figure(figsize=(8, 6))
plt.plot(x_new, y_new, 'b-')
plt.plot(x, y, 'ro')
plt.plot(x_target, y_target, 'go')
plt.title('Interpolasi Kecepatan Lari')
plt.xlabel('Jarak (meter)')
plt.ylabel('Kecepatan (m/detik)')
plt.grid()
plt.show()
